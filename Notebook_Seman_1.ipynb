# %% [markdown]
# <a href="https://colab.research.google.com/github/edilzabaletabasilio-ship-it/Notebooks_Agro-2026-1/blob/main/Notebook_Seman_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ENTRADA: entra ancho y alto de la madera en metros
ancho = input("Ingresa el ancho de la ventana en metros")
ancho = float(ancho)
alto = input("ingresa el alto de la ventana en metros")
alto = float(alto)

# POCESOS: calcula longitud de la madera (lm) en pies
# y el area del vidrio en centimetros
lm = 2 * (ancho + alto) * 3.25
av = 2 * (ancho * alto)

# SALIDA: sale la longitud de la amdera en pies
# el area del vidrio en metros cuadrdos
print("longitud de la madera es ", lm, " pies de longitud")
print("El area del vidrio es ", av, " metros cuadrados")
# Out:
# Ingresa el ancho de la ventana en metros1
# ingresa el alto de la ventana en metros2
# longitud de la madera es  19.5  pies de longitud
# El area del vidrio es  4.0  metros cuadrados
